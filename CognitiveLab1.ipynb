# %%
def add(a,b):
  print(a+b)
a = int(input('enter a number'))
b = int(input('enter b number'))
add(a,b)
# Out:
# enter a number2
# enter b number3
# 5

# %%
def prime(a):
  for i in range (2,a//2+1,1):
    if(a%i==0):
      print('not prime')
      return 0
      break
  print('prime')
  return 1
prime(23)
# Out:
# prime
# 1

# %%
for i in range (0,3,1):#Ques-1
  print('nityan')
# Out:
# nityan
# nityan
# nityan

# %%
a = int(input('enter a'))
b = int(input('enter b'))
c = int(input('enter c'))
print(a+b+c)
# Out:
# enter a23
# enter b34
# enter c45
# 102

# %%
a = str(input('enter a'))
b = str(input('enter b'))
c = str(input('enter c'))
print(a+b+c)
# Out:
# enter ahello
# enter bmy
# enter cworld
# hellomyworld

# %%
for i in range (1,11,1):
  print(7*i)

  print(9*i)
# Out:
# 7
# 9
# 14
# 18
# 21
# 27
# 28
# 36
# 35
# 45
# 42
# 54
# 49
# 63
# 56
# 72
# 63
# 81
# 70
# 90

# %%
n = int(input('enter n'))
for i in range (1,11,1):
  print(n*i)
# Out:
# enter n23
# 23
# 46
# 69
# 92
# 115
# 138
# 161
# 184
# 207
# 230

# %%
sum = 0
n = int(input('enter n'))
for i in range (1,n+1,1):
  sum+=i
print(sum)
# Out:
# enter n23
# 276

# %%
from math import inf
a = int(input('enter a'))
b = int(input('enter b'))
c = int(input('enter c'))
l = [a,b,c]

n = -inf
for i in l:
  if(i>n):
    n = i
print(n)
# Out:
# enter a23
# enter b57
# enter c12
# 57

# %%
def addOdd(n):
  sum = 0
  for i in range (1,n+1,2):
    sum+=i
  print(sum)
n = int(input('enter number'))
addOdd(n)
# Out:
# enter number8
# 16
